# %% [markdown]
# #Assignment Set 1
# by **Amir Mehrpanah** for [Deep Learing](https://github.com/hhaji/Deep-Learning/tree/master/Recitation-Assignments) Course at Data Science Center, SBU

# %%
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
import sklearn
import tensorflow as tf
import torch

# %%
print("Scikit-learn Version: ", sklearn.__version__)
print("TensorFlow Version: ", tf.__version__)
print("PyTorch Version: ", torch.__version__)
# Out:
# Scikit-learn Version:  0.22.2.post1
# TensorFlow Version:  2.3.0
# PyTorch Version:  1.6.0+cu101

# %%
start_time = time.time()
data = {'a': np.arange(500),
        'c': np.random.randint(0, 500, 500),
        'd': np.random.randn(500)}
data['b'] = data['a'] + 5 * np.random.randn(500)
data['d'] = np.abs(data['d']) * 100
plt.scatter('a', 'b', c='c', s='d', data=data)
plt.xlabel('A')
plt.ylabel('B')
plt.show()
df = pd.DataFrame(np.random.randn(10, 5)) 
print(df)
j=np.pi
for i in range(100000000):
  j+=j    
print("\n-> Execution Time = %s in Seconds <-" % (time.time() - start_time))
# Out:
#           0         1         2         3         4
# 0 -0.890769 -0.273582 -0.916116 -1.826215  1.746174
# 1  0.114994 -1.654566  0.017853  0.175290  0.613135
# 2 -1.780149 -1.573825  0.043079 -0.093724 -1.972472
# 3 -0.357101 -1.266051  0.480655  0.463960 -1.023262
# 4 -0.865303 -0.546320  1.528181 -0.079422  0.880844
# 5  1.827513 -0.930667 -0.388504 -0.346156 -0.725391
# 6 -1.466238 -0.708955  0.129570  1.998594  0.699295
# 7  1.437229  1.215297 -2.162449 -0.885257 -0.551838
# 8  0.755222 -1.223054 -0.047539  1.199841  1.768927
# 9  1.371960  0.341328  0.676655  2.203558  0.539363
#
# -> Execution Time = 11.53775691986084 in Seconds <-
